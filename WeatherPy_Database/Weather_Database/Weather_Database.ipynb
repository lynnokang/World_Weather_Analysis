# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the API key.
from config  import weather_api_keys
from random import randint
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("../cities.csv")
city_data_df.head()
# Out:
#    City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0       Mayya  61.7333  130.2811     14.00        67           0
# 1        1   Ostrovnoy  68.0531   39.5131     34.00        96         100
# 2        2  Kaitangata -46.2817  169.8464     53.35        97         100
# 3        3     Ushuaia -54.8000  -68.3000     48.20        71          75
# 4        4    Khanbari  27.3747   87.2039     73.96        31         100
#
#    Wind Speed Country                 Date
# 0        4.47      RU  2021-03-30 12:12:35
# 1       17.27      RU  2021-03-30 12:12:36
# 2        2.48      NZ  2021-03-30 12:12:36
# 3       41.43      AR  2021-03-30 12:11:53
# 4        6.53      NP  2021-03-30 12:12:36

# %%
# Create a set of random latitude and longitude combinations.
latitude = np.random.randint(low=-90.000, high=90.000, size=2000)
longitude = np.random.randint(low=-180.000, high=180.000, size=2000)
latitude_longitude = zip(latitude, longitude)
latitude_longitude

# %%
import sys
sys.path.insert(0, '../')

# %%
# Creating a list
coordinates = list(latitude_longitude)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_keys
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e2bc90f5254751268ceffe0a68e59eb9

# %%
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
weather_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
     # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
          # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        weather_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kanniyakumari
# Processing Record 2 of Set 1 | namatanai
# Processing Record 3 of Set 1 | tiksi
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | tasiilaq
# Processing Record 6 of Set 1 | placido de castro
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | mineros
# Processing Record 9 of Set 1 | russas
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | ribeira grande
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | brae
# Processing Record 15 of Set 1 | luwuk
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | saint-augustin
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | san cristobal
# Processing Record 21 of Set 1 | korla
# Processing Record 22 of Set 1 | ulaanbaatar
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | moree
# Processing Record 26 of Set 1 | ixtapa
# Processing Record 27 of Set 1 | guanica
# Processing Record 28 of Set 1 | killybegs
# Processing Record 29 of Set 1 | karachi
# Processing Record 30 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 1 | salalah
# Processing Record 32 of Set 1 | sao filipe
# Processing Record 33 of Set 1 | geraldton
# Processing Record 34 of Set 1 | yeppoon
# Processing Record 35 of Set 1 | kapoeta
# Processing Record 36 of Set 1 | yarmouth
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | talaya
# Processing Record 40 of Set 1 | nabire
# Processing Record 41 of Set 1 | provideniya
# Processing Record 42 of Set 1 | nikolskoye
# Processing Record 43 of Set 1 | butaritari
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | san miguel
# Processing Record 46 of Set 1 | pevek
# Processing Record 47 of Set 1 | valley city
# Processing Record 48 of Set 1 | sarahan
# Processing Record 49 of Set 1 | ambilobe
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | neuquen
# Processing Record 4 of Set 2 | pizhma
# Processing Record 5 of Set 2 | santa cruz
# Processing Record 6 of Set 2 | kodiak
# Processing Record 7 of Set 2 | susurluk
# Processing Record 8 of Set 2 | tautira
# Processing Record 9 of Set 2 | saint george
# Processing Record 10 of Set 2 | poum
# Processing Record 11 of Set 2 | iracoubo
# Processing Record 12 of Set 2 | meulaboh
# Processing Record 13 of Set 2 | erzin
# Processing Record 14 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 2 | spas
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | afmadu
# City not found. Skipping...
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | iranshahr
# Processing Record 20 of Set 2 | kailua
# Processing Record 21 of Set 2 | aksu
# Processing Record 22 of Set 2 | aden
# Processing Record 23 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 2 | teya
# Processing Record 26 of Set 2 | vila franca do campo
# Processing Record 27 of Set 2 | kilosa
# Processing Record 28 of Set 2 | vao
# Processing Record 29 of Set 2 | christchurch
# Processing Record 30 of Set 2 | chernyshevskiy
# Processing Record 31 of Set 2 | east london
# Processing Record 32 of Set 2 | lasa
# Processing Record 33 of Set 2 | port said
# Processing Record 34 of Set 2 | kearney
# Processing Record 35 of Set 2 | ostrovnoy
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | kavieng
# Processing Record 38 of Set 2 | quesnel
# Processing Record 39 of Set 2 | ushuaia
# Processing Record 40 of Set 2 | muisne
# Processing Record 41 of Set 2 | port alfred
# Processing Record 42 of Set 2 | iqaluit
# Processing Record 43 of Set 2 | torbay
# Processing Record 44 of Set 2 | mataura
# Processing Record 45 of Set 2 | amahai
# Processing Record 46 of Set 2 | leningradskiy
# Processing Record 47 of Set 2 | eureka
# Processing Record 48 of Set 2 | winnemucca
# Processing Record 49 of Set 2 | junin
# Processing Record 50 of Set 2 | mandsaur
# Processing Record 1 of Set 3 | hobart
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 3 | fort nelson
# Processing Record 5 of Set 3 | port hawkesbury
# Processing Record 6 of Set 3 | dikson
# Processing Record 7 of Set 3 | codrington
# Processing Record 8 of Set 3 | batticaloa
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | antsohihy
# Processing Record 11 of Set 3 | khatanga
# Processing Record 12 of Set 3 | nelson bay
# Processing Record 13 of Set 3 | mocuba
# Processing Record 14 of Set 3 | polonnaruwa
# Processing Record 15 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 3 | comodoro rivadavia
# Processing Record 17 of Set 3 | hilo
# Processing Record 18 of Set 3 | airai
# Processing Record 19 of Set 3 | kloulklubed
# Processing Record 20 of Set 3 | faanui
# Processing Record 21 of Set 3 | alta floresta
# Processing Record 22 of Set 3 | zabid
# Processing Record 23 of Set 3 | russell
# Processing Record 24 of Set 3 | concord
# Processing Record 25 of Set 3 | fortuna
# Processing Record 26 of Set 3 | saint-philippe
# Processing Record 27 of Set 3 | matara
# Processing Record 28 of Set 3 | bartica
# Processing Record 29 of Set 3 | arraial do cabo
# Processing Record 30 of Set 3 | mar del plata
# Processing Record 31 of Set 3 | ilulissat
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | kui buri
# Processing Record 34 of Set 3 | botshabelo
# Processing Record 35 of Set 3 | luganville
# Processing Record 36 of Set 3 | norman wells
# Processing Record 37 of Set 3 | saskylakh
# Processing Record 38 of Set 3 | carlos chagas
# Processing Record 39 of Set 3 | havre-saint-pierre
# Processing Record 40 of Set 3 | roma
# Processing Record 41 of Set 3 | bethel
# Processing Record 42 of Set 3 | bambous virieux
# Processing Record 43 of Set 3 | new norfolk
# Processing Record 44 of Set 3 | vikersund
# Processing Record 45 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 46 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 3 | ponta do sol
# Processing Record 48 of Set 3 | chokurdakh
# Processing Record 49 of Set 3 | cayenne
# Processing Record 50 of Set 3 | hithadhoo
# Processing Record 1 of Set 4 | dudinka
# Processing Record 2 of Set 4 | halifax
# Processing Record 3 of Set 4 | nyurba
# Processing Record 4 of Set 4 | bengkulu
# Processing Record 5 of Set 4 | okato
# Processing Record 6 of Set 4 | severnoye
# Processing Record 7 of Set 4 | mayumba
# Processing Record 8 of Set 4 | binga
# Processing Record 9 of Set 4 | melito di porto salvo
# Processing Record 10 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 11 of Set 4 | qui nhon
# Processing Record 12 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 4 | ondjiva
# Processing Record 14 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 4 | tsabong
# Processing Record 16 of Set 4 | winchester
# Processing Record 17 of Set 4 | kazuno
# Processing Record 18 of Set 4 | harper
# Processing Record 19 of Set 4 | okha
# Processing Record 20 of Set 4 | coria
# Processing Record 21 of Set 4 | shancheng
# Processing Record 22 of Set 4 | richards bay
# Processing Record 23 of Set 4 | lumeje
# Processing Record 24 of Set 4 | fuerte olimpo
# Processing Record 25 of Set 4 | klaksvik
# Processing Record 26 of Set 4 | hammerfest
# Processing Record 27 of Set 4 | dunedin
# Processing Record 28 of Set 4 | tuatapere
# Processing Record 29 of Set 4 | jaramana
# City not found. Skipping...
# Processing Record 30 of Set 4 | flinders
# Processing Record 31 of Set 4 | bonthe
# Processing Record 32 of Set 4 | kovdor
# Processing Record 33 of Set 4 | luwingu
# Processing Record 34 of Set 4 | port hedland
# Processing Record 35 of Set 4 | yazman
# Processing Record 36 of Set 4 | marawi
# Processing Record 37 of Set 4 | glasgow
# Processing Record 38 of Set 4 | coihaique
# Processing Record 39 of Set 4 | tevriz
# Processing Record 40 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 4 | lebanon
# Processing Record 42 of Set 4 | puerto ayora
# Processing Record 43 of Set 4 | cherskiy
# Processing Record 44 of Set 4 | port lincoln
# Processing Record 45 of Set 4 | clyde river
# Processing Record 46 of Set 4 | ugoofaaru
# Processing Record 47 of Set 4 | margate
# Processing Record 48 of Set 4 | atuona
# Processing Record 49 of Set 4 | bogorodskoye
# Processing Record 50 of Set 4 | marsa matruh
# Processing Record 1 of Set 5 | maua
# Processing Record 2 of Set 5 | vagamo
# Processing Record 3 of Set 5 | kawalu
# Processing Record 4 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 5 of Set 5 | velingara
# Processing Record 6 of Set 5 | malanje
# Processing Record 7 of Set 5 | pundaguitan
# Processing Record 8 of Set 5 | dengzhou
# Processing Record 9 of Set 5 | nome
# Processing Record 10 of Set 5 | imbituba
# Processing Record 11 of Set 5 | pyaozerskiy
# Processing Record 12 of Set 5 | touros
# Processing Record 13 of Set 5 | abu samrah
# Processing Record 14 of Set 5 | goryachegorsk
# Processing Record 15 of Set 5 | kyle
# Processing Record 16 of Set 5 | nouakchott
# Processing Record 17 of Set 5 | bubaque
# Processing Record 18 of Set 5 | chuy
# Processing Record 19 of Set 5 | yomitan
# City not found. Skipping...
# Processing Record 20 of Set 5 | mandalgovi
# Processing Record 21 of Set 5 | bukoba
# Processing Record 22 of Set 5 | kilis
# Processing Record 23 of Set 5 | lerik
# Processing Record 24 of Set 5 | nouadhibou
# Processing Record 25 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 26 of Set 5 | can
# Processing Record 27 of Set 5 | nanortalik
# Processing Record 28 of Set 5 | mahebourg
# Processing Record 29 of Set 5 | axim
# Processing Record 30 of Set 5 | rincon
# Processing Record 31 of Set 5 | slave lake
# Processing Record 32 of Set 5 | saint anthony
# Processing Record 33 of Set 5 | shimoda
# Processing Record 34 of Set 5 | kahului
# Processing Record 35 of Set 5 | carthage
# Processing Record 36 of Set 5 | santa lucia
# Processing Record 37 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 5 | murmansk
# Processing Record 39 of Set 5 | ellsworth
# Processing Record 40 of Set 5 | alta
# Processing Record 41 of Set 5 | santa isabel do rio negro
# Processing Record 42 of Set 5 | egvekinot
# Processing Record 43 of Set 5 | lagoa
# Processing Record 44 of Set 5 | bekasi
# Processing Record 45 of Set 5 | souillac
# Processing Record 46 of Set 5 | ahipara
# Processing Record 47 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 5 | karaton
# Processing Record 49 of Set 5 | marienburg
# Processing Record 50 of Set 5 | concordia
# Processing Record 1 of Set 6 | turmalina
# Processing Record 2 of Set 6 | tabou
# Processing Record 3 of Set 6 | bathsheba
# Processing Record 4 of Set 6 | naze
# Processing Record 5 of Set 6 | pitiquito
# Processing Record 6 of Set 6 | alofi
# Processing Record 7 of Set 6 | cidreira
# Processing Record 8 of Set 6 | kruisfontein
# Processing Record 9 of Set 6 | abancay
# Processing Record 10 of Set 6 | rawson
# Processing Record 11 of Set 6 | luanda
# Processing Record 12 of Set 6 | kenai
# Processing Record 13 of Set 6 | charters towers
# Processing Record 14 of Set 6 | saint-joseph
# Processing Record 15 of Set 6 | tura
# Processing Record 16 of Set 6 | povarovo
# Processing Record 17 of Set 6 | bilibino
# Processing Record 18 of Set 6 | gremyachye
# City not found. Skipping...
# Processing Record 19 of Set 6 | sur
# Processing Record 20 of Set 6 | temirtau
# Processing Record 21 of Set 6 | zermatt
# Processing Record 22 of Set 6 | nybro
# Processing Record 23 of Set 6 | cap malheureux
# Processing Record 24 of Set 6 | cienaga
# Processing Record 25 of Set 6 | wencheng
# Processing Record 26 of Set 6 | bail hongal
# Processing Record 27 of Set 6 | santa maria
# Processing Record 28 of Set 6 | batesville
# Processing Record 29 of Set 6 | aloleng
# Processing Record 30 of Set 6 | anloga
# Processing Record 31 of Set 6 | carbonia
# Processing Record 32 of Set 6 | pisco
# Processing Record 33 of Set 6 | salym
# Processing Record 34 of Set 6 | ozernovskiy
# Processing Record 35 of Set 6 | komsomolskiy
# Processing Record 36 of Set 6 | buritama
# Processing Record 37 of Set 6 | nisia floresta
# Processing Record 38 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 6 | rafai
# Processing Record 40 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 6 | rancho palos verdes
# Processing Record 42 of Set 6 | batagay
# Processing Record 43 of Set 6 | mackenzie
# Processing Record 44 of Set 6 | quelimane
# Processing Record 45 of Set 6 | gilgit
# Processing Record 46 of Set 6 | kinablangan
# Processing Record 47 of Set 6 | wanaka
# Processing Record 48 of Set 6 | torquay
# Processing Record 49 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 6 | haimen
# Processing Record 1 of Set 7 | half moon bay
# Processing Record 2 of Set 7 | cockburn town
# Processing Record 3 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 7 | kyra
# Processing Record 5 of Set 7 | carnarvon
# Processing Record 6 of Set 7 | xai-xai
# Processing Record 7 of Set 7 | la ronge
# Processing Record 8 of Set 7 | funtua
# Processing Record 9 of Set 7 | butembo
# Processing Record 10 of Set 7 | camopi
# Processing Record 11 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 7 | chulman
# Processing Record 13 of Set 7 | balakovo
# Processing Record 14 of Set 7 | maine-soroa
# Processing Record 15 of Set 7 | pierre
# Processing Record 16 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 17 of Set 7 | benguela
# Processing Record 18 of Set 7 | tiarei
# Processing Record 19 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 7 | cabo san lucas
# Processing Record 21 of Set 7 | galle
# Processing Record 22 of Set 7 | sioux lookout
# Processing Record 23 of Set 7 | posse
# Processing Record 24 of Set 7 | aklavik
# Processing Record 25 of Set 7 | ca mau
# Processing Record 26 of Set 7 | kisangani
# Processing Record 27 of Set 7 | manggar
# Processing Record 28 of Set 7 | constitucion
# Processing Record 29 of Set 7 | waipawa
# Processing Record 30 of Set 7 | dakar
# Processing Record 31 of Set 7 | piacabucu
# Processing Record 32 of Set 7 | solnechnyy
# Processing Record 33 of Set 7 | burnie
# Processing Record 34 of Set 7 | iskateley
# Processing Record 35 of Set 7 | mitzic
# Processing Record 36 of Set 7 | castro
# Processing Record 37 of Set 7 | benghazi
# Processing Record 38 of Set 7 | mokhsogollokh
# Processing Record 39 of Set 7 | zverinogolovskoye
# Processing Record 40 of Set 7 | mana
# Processing Record 41 of Set 7 | plouzane
# Processing Record 42 of Set 7 | cabinda
# Processing Record 43 of Set 7 | meadow lake
# Processing Record 44 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 7 | ust-maya
# Processing Record 46 of Set 7 | vardo
# Processing Record 47 of Set 7 | tandil
# Processing Record 48 of Set 7 | lorengau
# Processing Record 49 of Set 7 | paamiut
# Processing Record 50 of Set 7 | morondava
# Processing Record 1 of Set 8 | trairi
# Processing Record 2 of Set 8 | severo-kurilsk
# Processing Record 3 of Set 8 | hofn
# Processing Record 4 of Set 8 | grand island
# Processing Record 5 of Set 8 | aguada de pasajeros
# Processing Record 6 of Set 8 | chumikan
# Processing Record 7 of Set 8 | vila velha
# Processing Record 8 of Set 8 | doka
# Processing Record 9 of Set 8 | redmond
# Processing Record 10 of Set 8 | muros
# Processing Record 11 of Set 8 | gryfice
# Processing Record 12 of Set 8 | minervino murge
# Processing Record 13 of Set 8 | mikkeli
# Processing Record 14 of Set 8 | bayan
# Processing Record 15 of Set 8 | canaries
# Processing Record 16 of Set 8 | mount gambier
# Processing Record 17 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 8 | nishihara
# Processing Record 19 of Set 8 | port elizabeth
# Processing Record 20 of Set 8 | kasongo-lunda
# Processing Record 21 of Set 8 | newport
# Processing Record 22 of Set 8 | gat
# Processing Record 23 of Set 8 | maumere
# Processing Record 24 of Set 8 | jumla
# Processing Record 25 of Set 8 | asuncion
# Processing Record 26 of Set 8 | soligalich
# Processing Record 27 of Set 8 | kazerun
# Processing Record 28 of Set 8 | yerbogachen
# Processing Record 29 of Set 8 | lianzhou
# Processing Record 30 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 8 | bardiyah
# Processing Record 32 of Set 8 | broken hill
# Processing Record 33 of Set 8 | san patricio
# Processing Record 34 of Set 8 | meybod
# Processing Record 35 of Set 8 | oum hadjer
# Processing Record 36 of Set 8 | pacific grove
# Processing Record 37 of Set 8 | soyo
# Processing Record 38 of Set 8 | juba
# Processing Record 39 of Set 8 | dawlatabad
# Processing Record 40 of Set 8 | nantucket
# Processing Record 41 of Set 8 | kiruna
# Processing Record 42 of Set 8 | khasan
# Processing Record 43 of Set 8 | henties bay
# Processing Record 44 of Set 8 | shitanjing
# Processing Record 45 of Set 8 | bandarbeyla
# Processing Record 46 of Set 8 | balykshi
# Processing Record 47 of Set 8 | el faiyum
# City not found. Skipping...
# Processing Record 48 of Set 8 | zvenigovo
# Processing Record 49 of Set 8 | urbana
# Processing Record 50 of Set 8 | saldanha
# Processing Record 1 of Set 9 | chino valley
# Processing Record 2 of Set 9 | esperance
# Processing Record 3 of Set 9 | fairbanks
# Processing Record 4 of Set 9 | gurupi
# Processing Record 5 of Set 9 | san quintin
# Processing Record 6 of Set 9 | longyearbyen
# Processing Record 7 of Set 9 | winneba
# Processing Record 8 of Set 9 | lavrentiya
# Processing Record 9 of Set 9 | mora
# Processing Record 10 of Set 9 | kadambur
# Processing Record 11 of Set 9 | klyuchi
# Processing Record 12 of Set 9 | sangar
# Processing Record 13 of Set 9 | saskatoon
# Processing Record 14 of Set 9 | vanavara
# Processing Record 15 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 16 of Set 9 | zhangjiakou
# Processing Record 17 of Set 9 | udachnyy
# Processing Record 18 of Set 9 | tecoanapa
# Processing Record 19 of Set 9 | saint-francois
# Processing Record 20 of Set 9 | angoram
# Processing Record 21 of Set 9 | yatou
# Processing Record 22 of Set 9 | lere
# Processing Record 23 of Set 9 | batemans bay
# Processing Record 24 of Set 9 | nizhniy tagil
# Processing Record 25 of Set 9 | florianopolis
# Processing Record 26 of Set 9 | hasaki
# Processing Record 27 of Set 9 | palu
# Processing Record 28 of Set 9 | olafsvik
# Processing Record 29 of Set 9 | san clemente
# Processing Record 30 of Set 9 | westport
# Processing Record 31 of Set 9 | laguna
# Processing Record 32 of Set 9 | maykain
# City not found. Skipping...
# Processing Record 33 of Set 9 | palana
# Processing Record 34 of Set 9 | panaba
# Processing Record 35 of Set 9 | sola
# Processing Record 36 of Set 9 | mittweida
# Processing Record 37 of Set 9 | mount isa
# Processing Record 38 of Set 9 | gigmoto
# Processing Record 39 of Set 9 | povenets
# Processing Record 40 of Set 9 | artesia
# Processing Record 41 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 9 | kaitangata
# Processing Record 43 of Set 9 | seoul
# Processing Record 44 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 9 | narrabri
# Processing Record 46 of Set 9 | katsuura
# Processing Record 47 of Set 9 | esmeraldas
# Processing Record 48 of Set 9 | krasnokamensk
# Processing Record 49 of Set 9 | shasta lake
# Processing Record 50 of Set 9 | betioky
# Processing Record 1 of Set 10 | praia da vitoria
# Processing Record 2 of Set 10 | williamsport
# Processing Record 3 of Set 10 | palmer
# Processing Record 4 of Set 10 | vysokogornyy
# Processing Record 5 of Set 10 | kalas
# Processing Record 6 of Set 10 | dhankuta
# Processing Record 7 of Set 10 | lahij
# Processing Record 8 of Set 10 | bambanglipuro
# Processing Record 9 of Set 10 | kabalo
# Processing Record 10 of Set 10 | mehamn
# Processing Record 11 of Set 10 | olinda
# Processing Record 12 of Set 10 | svetlyy
# Processing Record 13 of Set 10 | ngunguru
# Processing Record 14 of Set 10 | sorland
# Processing Record 15 of Set 10 | krasnyy chikoy
# Processing Record 16 of Set 10 | kavaratti
# Processing Record 17 of Set 10 | tashara
# Processing Record 18 of Set 10 | gagnoa
# Processing Record 19 of Set 10 | phek
# Processing Record 20 of Set 10 | ust-nera
# Processing Record 21 of Set 10 | tunxi
# City not found. Skipping...
# Processing Record 22 of Set 10 | mamou
# Processing Record 23 of Set 10 | neyshabur
# Processing Record 24 of Set 10 | irbil
# Processing Record 25 of Set 10 | suozhen
# Processing Record 26 of Set 10 | gamba
# Processing Record 27 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 28 of Set 10 | darhan
# Processing Record 29 of Set 10 | manacapuru
# Processing Record 30 of Set 10 | lompoc
# Processing Record 31 of Set 10 | jackson
# Processing Record 32 of Set 10 | anaconda
# Processing Record 33 of Set 10 | tete
# Processing Record 34 of Set 10 | druskininkai
# Processing Record 35 of Set 10 | lata
# Processing Record 36 of Set 10 | sarandi
# Processing Record 37 of Set 10 | moyale
# Processing Record 38 of Set 10 | rostovka
# Processing Record 39 of Set 10 | laramie
# Processing Record 40 of Set 10 | tiznit
# Processing Record 41 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 42 of Set 10 | caravelas
# Processing Record 43 of Set 10 | necochea
# Processing Record 44 of Set 10 | quatre cocos
# Processing Record 45 of Set 10 | saint-pierre
# Processing Record 46 of Set 10 | aswan
# Processing Record 47 of Set 10 | tilichiki
# Processing Record 48 of Set 10 | kedrovyy
# Processing Record 49 of Set 10 | tigil
# Processing Record 50 of Set 10 | iralaya
# Processing Record 1 of Set 11 | tomatlan
# Processing Record 2 of Set 11 | maldonado
# Processing Record 3 of Set 11 | langsa
# Processing Record 4 of Set 11 | nanchong
# Processing Record 5 of Set 11 | sisimiut
# Processing Record 6 of Set 11 | talnakh
# Processing Record 7 of Set 11 | brownsville
# Processing Record 8 of Set 11 | westerland
# Processing Record 9 of Set 11 | morros
# Processing Record 10 of Set 11 | atambua
# Processing Record 11 of Set 11 | aktash
# Processing Record 12 of Set 11 | betanzos
# Processing Record 13 of Set 11 | lyaskelya
# Processing Record 14 of Set 11 | damietta
# Processing Record 15 of Set 11 | hvide sande
# Processing Record 16 of Set 11 | rutana
# Processing Record 17 of Set 11 | prince george
# Processing Record 18 of Set 11 | kalmunai
# Processing Record 19 of Set 11 | rocha
# Processing Record 20 of Set 11 | kieta
# Processing Record 21 of Set 11 | nuuk
# Processing Record 22 of Set 11 | agirish
# Processing Record 23 of Set 11 | berlevag
# Processing Record 24 of Set 11 | lodja
# Processing Record 25 of Set 11 | isangel
# Processing Record 26 of Set 11 | havelock
# Processing Record 27 of Set 11 | rock sound
# Processing Record 28 of Set 11 | ucluelet
# Processing Record 29 of Set 11 | ati
# Processing Record 30 of Set 11 | weihai
# Processing Record 31 of Set 11 | la asuncion
# Processing Record 32 of Set 11 | novikovo
# Processing Record 33 of Set 11 | baykit
# Processing Record 34 of Set 11 | yekaterinoslavka
# Processing Record 35 of Set 11 | chaman
# Processing Record 36 of Set 11 | luau
# Processing Record 37 of Set 11 | kant
# Processing Record 38 of Set 11 | suntar
# Processing Record 39 of Set 11 | samana
# Processing Record 40 of Set 11 | tarata
# Processing Record 41 of Set 11 | tefe
# Processing Record 42 of Set 11 | ekimchan
# Processing Record 43 of Set 11 | goderich
# Processing Record 44 of Set 11 | urubamba
# Processing Record 45 of Set 11 | srem
# Processing Record 46 of Set 11 | ambo
# Processing Record 47 of Set 11 | zharkent
# Processing Record 48 of Set 11 | three hills
# Processing Record 49 of Set 11 | tandalti
# Processing Record 50 of Set 11 | dongying
# Processing Record 1 of Set 12 | kununurra
# Processing Record 2 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 12 | port macquarie
# Processing Record 4 of Set 12 | vestmannaeyjar
# Processing Record 5 of Set 12 | semey
# Processing Record 6 of Set 12 | ternate
# Processing Record 7 of Set 12 | ancud
# Processing Record 8 of Set 12 | santa comba
# Processing Record 9 of Set 12 | ulundi
# Processing Record 10 of Set 12 | manadhoo
# Processing Record 11 of Set 12 | safaga
# Processing Record 12 of Set 12 | tabuk
# Processing Record 13 of Set 12 | inhambane
# Processing Record 14 of Set 12 | cururupu
# Processing Record 15 of Set 12 | guerrero negro
# Processing Record 16 of Set 12 | aberdeen
# Processing Record 17 of Set 12 | maniitsoq
# Processing Record 18 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 12 | tucuman
# Processing Record 20 of Set 12 | kumluca
# Processing Record 21 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 12 | lesogorskiy
# Processing Record 23 of Set 12 | sukumo
# Processing Record 24 of Set 12 | suhbaatar
# Processing Record 25 of Set 12 | salinopolis
# Processing Record 26 of Set 12 | praya
# Processing Record 27 of Set 12 | panzhihua
# Processing Record 28 of Set 12 | sechura
# Processing Record 29 of Set 12 | sitka
# Processing Record 30 of Set 12 | bilma
# Processing Record 31 of Set 12 | husavik
# Processing Record 32 of Set 12 | lafiagi
# Processing Record 33 of Set 12 | southbridge
# Processing Record 34 of Set 12 | gavle
# Processing Record 35 of Set 12 | dingle
# Processing Record 36 of Set 12 | tual
# Processing Record 37 of Set 12 | socorro
# Processing Record 38 of Set 12 | pamanukan
# Processing Record 39 of Set 12 | rio grande
# Processing Record 40 of Set 12 | shizilu
# Processing Record 41 of Set 12 | sakaiminato
# Processing Record 42 of Set 12 | diapaga
# Processing Record 43 of Set 12 | wuan
# Processing Record 44 of Set 12 | turinsk
# Processing Record 45 of Set 12 | hambantota
# Processing Record 46 of Set 12 | vangaindrano
# Processing Record 47 of Set 12 | teguise
# Processing Record 48 of Set 12 | port-gentil
# Processing Record 49 of Set 12 | lesnoy
# Processing Record 50 of Set 12 | roros
# Processing Record 1 of Set 13 | zhigansk
# Processing Record 2 of Set 13 | hervey bay
# Processing Record 3 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 4 of Set 13 | myitkyina
# Processing Record 5 of Set 13 | gushikawa
# Processing Record 6 of Set 13 | waddan
# Processing Record 7 of Set 13 | wilmington
# Processing Record 8 of Set 13 | faya
# Processing Record 9 of Set 13 | malindi
# Processing Record 10 of Set 13 | jashpurnagar
# Processing Record 11 of Set 13 | zhanaozen
# Processing Record 12 of Set 13 | pacifica
# Processing Record 13 of Set 13 | verkhnetulomskiy
# Processing Record 14 of Set 13 | ulverstone
# Processing Record 15 of Set 13 | coyuca
# City not found. Skipping...
# Processing Record 16 of Set 13 | hobyo
# Processing Record 17 of Set 13 | homer
# Processing Record 18 of Set 13 | keetmanshoop
# Processing Record 19 of Set 13 | yulara
# Processing Record 20 of Set 13 | honiara
# Processing Record 21 of Set 13 | miramar
# Processing Record 22 of Set 13 | warrington
# Processing Record 23 of Set 13 | kilkis
# Processing Record 24 of Set 13 | hailar
# Processing Record 25 of Set 13 | boffa
# Processing Record 26 of Set 13 | alice springs
# Processing Record 27 of Set 13 | bodden town
# Processing Record 28 of Set 13 | pangnirtung
# Processing Record 29 of Set 13 | bage
# Processing Record 30 of Set 13 | villa del rosario
# Processing Record 31 of Set 13 | antofagasta
# Processing Record 32 of Set 13 | pandan
# Processing Record 33 of Set 13 | impfondo
# Processing Record 34 of Set 13 | nhulunbuy
# Processing Record 35 of Set 13 | sept-iles
# Processing Record 36 of Set 13 | kurilsk
# Processing Record 37 of Set 13 | taltal
# Processing Record 38 of Set 13 | roald
# Processing Record 39 of Set 13 | surt
# Processing Record 40 of Set 13 | amuntai
# Processing Record 41 of Set 13 | natal
# Processing Record 42 of Set 13 | reconquista
# Processing Record 43 of Set 13 | banff
# Processing Record 44 of Set 13 | parral
# Processing Record 45 of Set 13 | zhangye
# Processing Record 46 of Set 13 | grindavik
# Processing Record 47 of Set 13 | krasnoselkup
# Processing Record 48 of Set 13 | caiaponia
# Processing Record 49 of Set 13 | farsund
# Processing Record 50 of Set 13 | nuevo progreso
# Processing Record 1 of Set 14 | bacolod
# Processing Record 2 of Set 14 | taoudenni
# Processing Record 3 of Set 14 | fayetteville
# Processing Record 4 of Set 14 | marsh harbour
# Processing Record 5 of Set 14 | san buenaventura
# Processing Record 6 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 7 of Set 14 | yangliuqing
# Processing Record 8 of Set 14 | batabano
# Processing Record 9 of Set 14 | zhezkazgan
# Processing Record 10 of Set 14 | portland
# Processing Record 11 of Set 14 | caraquet
# Processing Record 12 of Set 14 | bonavista
# Processing Record 13 of Set 14 | omboue
# Processing Record 14 of Set 14 | buchanan
# Processing Record 15 of Set 14 | garh maharaja
# Processing Record 16 of Set 14 | gayny
# Processing Record 17 of Set 14 | andenes
# Processing Record 18 of Set 14 | mlowo
# Processing Record 19 of Set 14 | namibe
# Processing Record 20 of Set 14 | minab
# Processing Record 21 of Set 14 | neman
# Processing Record 22 of Set 14 | fort smith
# Processing Record 23 of Set 14 | shchigry
# Processing Record 24 of Set 14 | duluth
# Processing Record 25 of Set 14 | fasa
# Processing Record 26 of Set 14 | te anau
# Processing Record 27 of Set 14 | hamilton
# Processing Record 28 of Set 14 | cap-haitien
# Processing Record 29 of Set 14 | kumba
# Processing Record 30 of Set 14 | antalaha
# Processing Record 31 of Set 14 | tornio
# Processing Record 32 of Set 14 | sinjai
# Processing Record 33 of Set 14 | narsaq
# Processing Record 34 of Set 14 | buraydah
# Processing Record 35 of Set 14 | talcahuano
# Processing Record 36 of Set 14 | valdivia
# Processing Record 37 of Set 14 | takoradi
# Processing Record 38 of Set 14 | waitati
# Processing Record 39 of Set 14 | abha
# Processing Record 40 of Set 14 | kalabo
# Processing Record 41 of Set 14 | synya
# Processing Record 42 of Set 14 | ostersund
# Processing Record 43 of Set 14 | kalianget
# Processing Record 44 of Set 14 | aripuana
# Processing Record 45 of Set 14 | petukhovo
# Processing Record 46 of Set 14 | shenjiamen
# Processing Record 47 of Set 14 | tam ky
# Processing Record 48 of Set 14 | koindu
# Processing Record 49 of Set 14 | sorong
# Processing Record 50 of Set 14 | itarema
# Processing Record 1 of Set 15 | acapulco
# Processing Record 2 of Set 15 | suamico
# Processing Record 3 of Set 15 | oktyabrskoye
# Processing Record 4 of Set 15 | werda
# Processing Record 5 of Set 15 | tamworth
# Processing Record 6 of Set 15 | san rafael
# Processing Record 7 of Set 15 | monte alegre de minas
# Processing Record 8 of Set 15 | loandjili
# Processing Record 9 of Set 15 | auki
# Processing Record 10 of Set 15 | lujan
# Processing Record 11 of Set 15 | thinadhoo
# Processing Record 12 of Set 15 | marquette
# Processing Record 13 of Set 15 | pitimbu
# Processing Record 14 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 15 of Set 15 | kraskino
# Processing Record 16 of Set 15 | ormara
# Processing Record 17 of Set 15 | new haven
# Processing Record 18 of Set 15 | tabas
# Processing Record 19 of Set 15 | broome
# Processing Record 20 of Set 15 | tres passos
# Processing Record 21 of Set 15 | jiuquan
# Processing Record 22 of Set 15 | ajdabiya
# Processing Record 23 of Set 15 | asyut
# Processing Record 24 of Set 15 | qandala
# Processing Record 25 of Set 15 | ginda
# Processing Record 26 of Set 15 | mitchell
# Processing Record 27 of Set 15 | cairns
# Processing Record 28 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 15 | kharan
# Processing Record 30 of Set 15 | carahue
# Processing Record 31 of Set 15 | dzaoudzi
# Processing Record 32 of Set 15 | gbarnga
# Processing Record 33 of Set 15 | mangrol
# Processing Record 34 of Set 15 | marshall
# Processing Record 35 of Set 15 | zeya
# Processing Record 36 of Set 15 | sayyan
# Processing Record 37 of Set 15 | south lake tahoe
# Processing Record 38 of Set 15 | rodrigues alves
# Processing Record 39 of Set 15 | rosetown
# Processing Record 40 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 41 of Set 15 | lincoln
# Processing Record 42 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 15 | konevo
# Processing Record 44 of Set 15 | champerico
# Processing Record 45 of Set 15 | beringovskiy
# Processing Record 46 of Set 15 | houston
# Processing Record 47 of Set 15 | nzerekore
# Processing Record 48 of Set 15 | urumqi
# Processing Record 49 of Set 15 | karratha
# Processing Record 50 of Set 15 | ayan
# Processing Record 1 of Set 16 | carinhanha
# Processing Record 2 of Set 16 | akureyri
# Processing Record 3 of Set 16 | ukiah
# Processing Record 4 of Set 16 | ichinoseki
# Processing Record 5 of Set 16 | qaqortoq
# Processing Record 6 of Set 16 | barbar
# City not found. Skipping...
# Processing Record 7 of Set 16 | abu dhabi
# Processing Record 8 of Set 16 | farafangana
# Processing Record 9 of Set 16 | irece
# Processing Record 10 of Set 16 | bowen
# Processing Record 11 of Set 16 | storforshei
# Processing Record 12 of Set 16 | kavalerovo
# Processing Record 13 of Set 16 | coruripe
# Processing Record 14 of Set 16 | mazagao
# Processing Record 15 of Set 16 | somerset
# Processing Record 16 of Set 16 | san lawrenz
# Processing Record 17 of Set 16 | marck
# Processing Record 18 of Set 16 | calceta
# Processing Record 19 of Set 16 | la rioja
# Processing Record 20 of Set 16 | yumen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
weather_data_df = pd.DataFrame(weather_data)
weather_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kanniyakumari   8.0833   77.5667     86.29        68          69
# 1          Namatanai  -3.6667  152.4333     83.89        74          85
# 2              Tiksi  71.6872  128.8694     31.48        90          96
# 3          Busselton -33.6500  115.3333     70.00        68          69
# 4           Tasiilaq  65.6145  -37.6368     26.60        68           9
# 5  Placido De Castro -10.3353  -67.1856     74.35        82          79
# 6              Bluff -46.6000  168.3333     46.99        88          94
# 7            Mineros -17.1167  -63.2333     73.40        88          75
# 8             Russas  -4.9403  -37.9758     72.19        88          10
# 9        Tuktoyaktuk  69.4541 -133.0374     30.20        86           1
#
#    Wind Speed Country                 Date
# 0       15.70      IN  2021-05-17 05:47:11
# 1       11.48      PG  2021-05-17 05:47:11
# 2        7.34      RU  2021-05-17 05:47:11
# 3        8.99      AU  2021-05-17 05:47:11
# 4        3.44      GL  2021-05-17 05:47:12
# 5        1.45      BR  2021-05-17 05:47:12
# 6        5.01      NZ  2021-05-17 05:47:12
# 7        3.44      BO  2021-05-17 05:47:12
# 8        4.54      BR  2021-05-17 05:47:12
# 9       14.97      CA  2021-05-17 05:47:13

# %%
#Change order of columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
df = weather_data_df[new_column_order]
df.head(10)
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0      Kanniyakumari      IN  2021-05-17 05:47:11   8.0833   77.5667
# 1          Namatanai      PG  2021-05-17 05:47:11  -3.6667  152.4333
# 2              Tiksi      RU  2021-05-17 05:47:11  71.6872  128.8694
# 3          Busselton      AU  2021-05-17 05:47:11 -33.6500  115.3333
# 4           Tasiilaq      GL  2021-05-17 05:47:12  65.6145  -37.6368
# 5  Placido De Castro      BR  2021-05-17 05:47:12 -10.3353  -67.1856
# 6              Bluff      NZ  2021-05-17 05:47:12 -46.6000  168.3333
# 7            Mineros      BO  2021-05-17 05:47:12 -17.1167  -63.2333
# 8             Russas      BR  2021-05-17 05:47:12  -4.9403  -37.9758
# 9        Tuktoyaktuk      CA  2021-05-17 05:47:13  69.4541 -133.0374
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     86.29        68          69       15.70
# 1     83.89        74          85       11.48
# 2     31.48        90          96        7.34
# 3     70.00        68          69        8.99
# 4     26.60        68           9        3.44
# 5     74.35        82          79        1.45
# 6     46.99        88          94        5.01
# 7     73.40        88          75        3.44
# 8     72.19        88          10        4.54
# 9     30.20        86           1       14.97

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
