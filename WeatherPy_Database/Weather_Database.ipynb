# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the API key.
from config  import weather_api_keys
from random import randint
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("../cities.csv")
city_data_df.head()
# Out:
#    City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0       Mayya  61.7333  130.2811     14.00        67           0
# 1        1   Ostrovnoy  68.0531   39.5131     34.00        96         100
# 2        2  Kaitangata -46.2817  169.8464     53.35        97         100
# 3        3     Ushuaia -54.8000  -68.3000     48.20        71          75
# 4        4    Khanbari  27.3747   87.2039     73.96        31         100
#
#    Wind Speed Country                 Date
# 0        4.47      RU  2021-03-30 12:12:35
# 1       17.27      RU  2021-03-30 12:12:36
# 2        2.48      NZ  2021-03-30 12:12:36
# 3       41.43      AR  2021-03-30 12:11:53
# 4        6.53      NP  2021-03-30 12:12:36

# %%
# Create a set of random latitude and longitude combinations.
latitude = np.random.randint(low=-90.000, high=90.000, size=2000)
longitude = np.random.randint(low=-180.000, high=180.000, size=2000)
latitude_longitude = zip(latitude, longitude)
latitude_longitude

# %%
# Creating a list
coordinates = list(latitude_longitude)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_keys
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e2bc90f5254751268ceffe0a68e59eb9

# %%
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
weather_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
     # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
          # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        weather_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vila velha
# Processing Record 2 of Set 1 | ponta do sol
# Processing Record 3 of Set 1 | apomu
# Processing Record 4 of Set 1 | hovd
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | assiniboia
# Processing Record 8 of Set 1 | salalah
# Processing Record 9 of Set 1 | neryungri
# Processing Record 10 of Set 1 | hamilton
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | pisco
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | half moon bay
# Processing Record 18 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 21 of Set 1 | hasaki
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | elizabeth city
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | paita
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | san patricio
# Processing Record 29 of Set 1 | fevralsk
# City not found. Skipping...
# Processing Record 30 of Set 1 | mahajanga
# Processing Record 31 of Set 1 | jeremoabo
# Processing Record 32 of Set 1 | longyearbyen
# Processing Record 33 of Set 1 | mezen
# Processing Record 34 of Set 1 | constitucion
# Processing Record 35 of Set 1 | jieshi
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | peachland
# Processing Record 38 of Set 1 | ambilobe
# Processing Record 39 of Set 1 | lesosibirsk
# Processing Record 40 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 1 | gazli
# Processing Record 42 of Set 1 | alta floresta
# Processing Record 43 of Set 1 | nome
# Processing Record 44 of Set 1 | bengkulu
# Processing Record 45 of Set 1 | henties bay
# Processing Record 46 of Set 1 | karakendzha
# City not found. Skipping...
# Processing Record 47 of Set 1 | jatibonico
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | norman wells
# Processing Record 50 of Set 1 | bonavista
# Processing Record 1 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | saskylakh
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | banda aceh
# Processing Record 6 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 2 | rosetta
# Processing Record 8 of Set 2 | rawson
# Processing Record 9 of Set 2 | tigil
# Processing Record 10 of Set 2 | upernavik
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | requena
# Processing Record 13 of Set 2 | broome
# Processing Record 14 of Set 2 | ushuaia
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 2 | east london
# Processing Record 19 of Set 2 | cumaribo
# City not found. Skipping...
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | maldonado
# Processing Record 22 of Set 2 | itarema
# Processing Record 23 of Set 2 | rocha
# Processing Record 24 of Set 2 | price
# Processing Record 25 of Set 2 | plouzane
# Processing Record 26 of Set 2 | georgetown
# Processing Record 27 of Set 2 | makakilo city
# Processing Record 28 of Set 2 | kopyevo
# City not found. Skipping...
# Processing Record 29 of Set 2 | kodiak
# Processing Record 30 of Set 2 | isangel
# Processing Record 31 of Set 2 | punta arenas
# Processing Record 32 of Set 2 | mwinilunga
# Processing Record 33 of Set 2 | port-gentil
# Processing Record 34 of Set 2 | pucallpa
# Processing Record 35 of Set 2 | hobart
# Processing Record 36 of Set 2 | sept-iles
# Processing Record 37 of Set 2 | nemuro
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | portland
# Processing Record 40 of Set 2 | san cristobal
# Processing Record 41 of Set 2 | saint anthony
# Processing Record 42 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 2 | grindavik
# Processing Record 44 of Set 2 | ilhabela
# Processing Record 45 of Set 2 | bluff
# Processing Record 46 of Set 2 | triel-sur-seine
# Processing Record 47 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 2 | ancud
# Processing Record 49 of Set 2 | eirunepe
# Processing Record 50 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 3 | saint-raymond
# Processing Record 2 of Set 3 | flinders
# Processing Record 3 of Set 3 | alihe
# Processing Record 4 of Set 3 | vestmannaeyjar
# Processing Record 5 of Set 3 | oktyabrskoye
# Processing Record 6 of Set 3 | carnarvon
# Processing Record 7 of Set 3 | manoel urbano
# Processing Record 8 of Set 3 | lebu
# Processing Record 9 of Set 3 | jamestown
# Processing Record 10 of Set 3 | bethel
# Processing Record 11 of Set 3 | kavieng
# Processing Record 12 of Set 3 | bezhta
# Processing Record 13 of Set 3 | komsomolskiy
# Processing Record 14 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 3 | sistranda
# Processing Record 16 of Set 3 | bambous virieux
# Processing Record 17 of Set 3 | waingapu
# Processing Record 18 of Set 3 | severo-kurilsk
# Processing Record 19 of Set 3 | kaitangata
# Processing Record 20 of Set 3 | atuona
# Processing Record 21 of Set 3 | san lawrenz
# Processing Record 22 of Set 3 | ilulissat
# Processing Record 23 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 24 of Set 3 | ahipara
# Processing Record 25 of Set 3 | meadow lake
# Processing Record 26 of Set 3 | carbonear
# Processing Record 27 of Set 3 | ketchikan
# Processing Record 28 of Set 3 | hastings
# Processing Record 29 of Set 3 | jhikargachha
# City not found. Skipping...
# Processing Record 30 of Set 3 | rzeszow
# Processing Record 31 of Set 3 | kadiri
# Processing Record 32 of Set 3 | chernyshevskiy
# Processing Record 33 of Set 3 | pevek
# Processing Record 34 of Set 3 | thompson
# Processing Record 35 of Set 3 | tuatapere
# Processing Record 36 of Set 3 | ivanovo
# Processing Record 37 of Set 3 | lorengau
# Processing Record 38 of Set 3 | leningradskiy
# Processing Record 39 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 3 | lavrentiya
# Processing Record 41 of Set 3 | gairo
# Processing Record 42 of Set 3 | cherskiy
# Processing Record 43 of Set 3 | port blair
# Processing Record 44 of Set 3 | linguere
# Processing Record 45 of Set 3 | saint-pierre
# Processing Record 46 of Set 3 | narsaq
# Processing Record 47 of Set 3 | brae
# Processing Record 48 of Set 3 | kampene
# Processing Record 49 of Set 3 | nisia floresta
# Processing Record 50 of Set 3 | seoul
# Processing Record 1 of Set 4 | srednekolymsk
# Processing Record 2 of Set 4 | lompoc
# Processing Record 3 of Set 4 | songjianghe
# Processing Record 4 of Set 4 | ostrovnoy
# Processing Record 5 of Set 4 | dikson
# Processing Record 6 of Set 4 | porto santo
# Processing Record 7 of Set 4 | sebina
# Processing Record 8 of Set 4 | cabo san lucas
# Processing Record 9 of Set 4 | airai
# Processing Record 10 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 11 of Set 4 | hwange
# Processing Record 12 of Set 4 | esperance
# Processing Record 13 of Set 4 | kaseda
# Processing Record 14 of Set 4 | pemba
# Processing Record 15 of Set 4 | dickinson
# Processing Record 16 of Set 4 | umm lajj
# Processing Record 17 of Set 4 | tongren
# Processing Record 18 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 4 | dergachi
# Processing Record 20 of Set 4 | sao filipe
# Processing Record 21 of Set 4 | mbigou
# Processing Record 22 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing Record 23 of Set 4 | hirara
# Processing Record 24 of Set 4 | chokurdakh
# Processing Record 25 of Set 4 | urucui
# Processing Record 26 of Set 4 | aykhal
# Processing Record 27 of Set 4 | olga
# Processing Record 28 of Set 4 | matam
# Processing Record 29 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 4 | salym
# Processing Record 31 of Set 4 | hami
# Processing Record 32 of Set 4 | montale
# Processing Record 33 of Set 4 | sur
# Processing Record 34 of Set 4 | erzurum
# Processing Record 35 of Set 4 | naze
# Processing Record 36 of Set 4 | riyadh
# Processing Record 37 of Set 4 | nabire
# Processing Record 38 of Set 4 | hofn
# Processing Record 39 of Set 4 | rio grande
# Processing Record 40 of Set 4 | puerto ayora
# Processing Record 41 of Set 4 | kirakira
# Processing Record 42 of Set 4 | cap malheureux
# Processing Record 43 of Set 4 | misratah
# Processing Record 44 of Set 4 | alur
# Processing Record 45 of Set 4 | nikolskoye
# Processing Record 46 of Set 4 | rio gallegos
# Processing Record 47 of Set 4 | takoradi
# Processing Record 48 of Set 4 | tiznit
# Processing Record 49 of Set 4 | srem
# Processing Record 50 of Set 4 | bairiki
# Processing Record 1 of Set 5 | arrecife
# Processing Record 2 of Set 5 | yian
# City not found. Skipping...
# Processing Record 3 of Set 5 | sitka
# Processing Record 4 of Set 5 | villa bruzual
# Processing Record 5 of Set 5 | ribeira grande
# Processing Record 6 of Set 5 | barentu
# Processing Record 7 of Set 5 | paveh
# Processing Record 8 of Set 5 | tasiilaq
# Processing Record 9 of Set 5 | samarai
# Processing Record 10 of Set 5 | karratha
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | yafran
# Processing Record 13 of Set 5 | mar del plata
# Processing Record 14 of Set 5 | la ronge
# Processing Record 15 of Set 5 | umm kaddadah
# Processing Record 16 of Set 5 | khatanga
# Processing Record 17 of Set 5 | alice springs
# Processing Record 18 of Set 5 | shenjiamen
# Processing Record 19 of Set 5 | lethem
# Processing Record 20 of Set 5 | namatanai
# Processing Record 21 of Set 5 | trincomalee
# Processing Record 22 of Set 5 | havre-saint-pierre
# Processing Record 23 of Set 5 | vilhena
# Processing Record 24 of Set 5 | porangatu
# Processing Record 25 of Set 5 | anloga
# Processing Record 26 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 5 | karaton
# Processing Record 28 of Set 5 | teya
# Processing Record 29 of Set 5 | southampton
# Processing Record 30 of Set 5 | ishigaki
# Processing Record 31 of Set 5 | pyshma
# Processing Record 32 of Set 5 | los llanos de aridane
# Processing Record 33 of Set 5 | saint-augustin
# Processing Record 34 of Set 5 | santa cruz
# Processing Record 35 of Set 5 | road town
# Processing Record 36 of Set 5 | torbay
# Processing Record 37 of Set 5 | barnbach
# Processing Record 38 of Set 5 | aktau
# Processing Record 39 of Set 5 | huarmey
# Processing Record 40 of Set 5 | north bend
# Processing Record 41 of Set 5 | springfield
# Processing Record 42 of Set 5 | washim
# Processing Record 43 of Set 5 | pitimbu
# Processing Record 44 of Set 5 | kasongo-lunda
# Processing Record 45 of Set 5 | imbituba
# Processing Record 46 of Set 5 | chitral
# Processing Record 47 of Set 5 | laguna
# Processing Record 48 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 5 | sioux lookout
# Processing Record 1 of Set 6 | karpogory
# Processing Record 2 of Set 6 | san matias
# Processing Record 3 of Set 6 | dalby
# Processing Record 4 of Set 6 | norden
# Processing Record 5 of Set 6 | ust-koksa
# Processing Record 6 of Set 6 | solnechnyy
# Processing Record 7 of Set 6 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 8 of Set 6 | tual
# Processing Record 9 of Set 6 | vao
# Processing Record 10 of Set 6 | bowen
# Processing Record 11 of Set 6 | mahebourg
# Processing Record 12 of Set 6 | lasa
# Processing Record 13 of Set 6 | tessalit
# Processing Record 14 of Set 6 | buenaventura
# Processing Record 15 of Set 6 | hobyo
# Processing Record 16 of Set 6 | gouyave
# Processing Record 17 of Set 6 | gorontalo
# Processing Record 18 of Set 6 | adrar
# Processing Record 19 of Set 6 | fairbanks
# Processing Record 20 of Set 6 | sola
# Processing Record 21 of Set 6 | bilma
# Processing Record 22 of Set 6 | bandrele
# Processing Record 23 of Set 6 | maceio
# Processing Record 24 of Set 6 | sayyan
# Processing Record 25 of Set 6 | oum hadjer
# Processing Record 26 of Set 6 | shebunino
# Processing Record 27 of Set 6 | kruisfontein
# Processing Record 28 of Set 6 | south lake tahoe
# Processing Record 29 of Set 6 | vitorino freire
# Processing Record 30 of Set 6 | hambantota
# Processing Record 31 of Set 6 | letterkenny
# Processing Record 32 of Set 6 | roebourne
# Processing Record 33 of Set 6 | bam
# Processing Record 34 of Set 6 | caranavi
# Processing Record 35 of Set 6 | kijang
# Processing Record 36 of Set 6 | necochea
# Processing Record 37 of Set 6 | wanning
# Processing Record 38 of Set 6 | iqaluit
# Processing Record 39 of Set 6 | esmeraldas
# Processing Record 40 of Set 6 | kununurra
# Processing Record 41 of Set 6 | vanimo
# Processing Record 42 of Set 6 | cairns
# Processing Record 43 of Set 6 | kibre mengist
# Processing Record 44 of Set 6 | saint-philippe
# Processing Record 45 of Set 6 | cidreira
# Processing Record 46 of Set 6 | tiksi
# Processing Record 47 of Set 6 | coquimbo
# Processing Record 48 of Set 6 | ende
# Processing Record 49 of Set 6 | caravelas
# Processing Record 50 of Set 6 | belyy yar
# Processing Record 1 of Set 7 | treuchtlingen
# Processing Record 2 of Set 7 | port lincoln
# Processing Record 3 of Set 7 | geraldton
# Processing Record 4 of Set 7 | ust-nera
# Processing Record 5 of Set 7 | forest acres
# Processing Record 6 of Set 7 | kautokeino
# Processing Record 7 of Set 7 | te anau
# Processing Record 8 of Set 7 | kungurtug
# Processing Record 9 of Set 7 | kletskaya
# Processing Record 10 of Set 7 | la seyne-sur-mer
# Processing Record 11 of Set 7 | sembe
# Processing Record 12 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 7 | gerardmer
# Processing Record 14 of Set 7 | burgeo
# Processing Record 15 of Set 7 | tilichiki
# Processing Record 16 of Set 7 | yenagoa
# Processing Record 17 of Set 7 | olafsvik
# Processing Record 18 of Set 7 | guerrero negro
# Processing Record 19 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 7 | fortuna
# Processing Record 21 of Set 7 | sambava
# Processing Record 22 of Set 7 | bahia blanca
# Processing Record 23 of Set 7 | tamiahua
# Processing Record 24 of Set 7 | kamaishi
# Processing Record 25 of Set 7 | tignere
# Processing Record 26 of Set 7 | grand gaube
# Processing Record 27 of Set 7 | krasnoselkup
# Processing Record 28 of Set 7 | koumac
# Processing Record 29 of Set 7 | curillo
# Processing Record 30 of Set 7 | xichang
# Processing Record 31 of Set 7 | burnie
# Processing Record 32 of Set 7 | tonstad
# Processing Record 33 of Set 7 | dingle
# Processing Record 34 of Set 7 | dombarovskiy
# Processing Record 35 of Set 7 | havre
# Processing Record 36 of Set 7 | klaksvik
# Processing Record 37 of Set 7 | plettenberg bay
# Processing Record 38 of Set 7 | agdam
# Processing Record 39 of Set 7 | santa
# Processing Record 40 of Set 7 | owando
# Processing Record 41 of Set 7 | maxixe
# Processing Record 42 of Set 7 | nishihara
# Processing Record 43 of Set 7 | artesia
# Processing Record 44 of Set 7 | spencer
# Processing Record 45 of Set 7 | rochelle
# Processing Record 46 of Set 7 | axim
# Processing Record 47 of Set 7 | codrington
# Processing Record 48 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 7 | souillac
# Processing Record 50 of Set 7 | shar
# Processing Record 1 of Set 8 | ternate
# Processing Record 2 of Set 8 | mbandaka
# Processing Record 3 of Set 8 | sinjah
# City not found. Skipping...
# Processing Record 4 of Set 8 | juruti
# Processing Record 5 of Set 8 | itacoatiara
# Processing Record 6 of Set 8 | taicheng
# Processing Record 7 of Set 8 | kopervik
# Processing Record 8 of Set 8 | biak
# Processing Record 9 of Set 8 | putina
# Processing Record 10 of Set 8 | coihaique
# Processing Record 11 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 8 | victoria
# Processing Record 13 of Set 8 | totma
# Processing Record 14 of Set 8 | san francisco
# Processing Record 15 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 8 | caiaponia
# Processing Record 17 of Set 8 | kamenka
# Processing Record 18 of Set 8 | port hardy
# Processing Record 19 of Set 8 | pouso alegre
# Processing Record 20 of Set 8 | udachnyy
# Processing Record 21 of Set 8 | port keats
# Processing Record 22 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 8 | luanda
# Processing Record 24 of Set 8 | junin
# Processing Record 25 of Set 8 | bonthe
# Processing Record 26 of Set 8 | sakaraha
# Processing Record 27 of Set 8 | lata
# Processing Record 28 of Set 8 | yeppoon
# Processing Record 29 of Set 8 | padang
# Processing Record 30 of Set 8 | ybycui
# Processing Record 31 of Set 8 | batticaloa
# Processing Record 32 of Set 8 | clyde river
# Processing Record 33 of Set 8 | keelung
# Processing Record 34 of Set 8 | surt
# Processing Record 35 of Set 8 | provideniya
# Processing Record 36 of Set 8 | phalaborwa
# Processing Record 37 of Set 8 | lagoa
# Processing Record 38 of Set 8 | madang
# Processing Record 39 of Set 8 | pacifica
# Processing Record 40 of Set 8 | mirandopolis
# Processing Record 41 of Set 8 | bow island
# Processing Record 42 of Set 8 | fort nelson
# Processing Record 43 of Set 8 | eganville
# Processing Record 44 of Set 8 | kommunisticheskiy
# Processing Record 45 of Set 8 | ixtapa
# Processing Record 46 of Set 8 | archidona
# Processing Record 47 of Set 8 | chimbote
# Processing Record 48 of Set 8 | quatre cocos
# Processing Record 49 of Set 8 | svetlaya
# Processing Record 50 of Set 8 | hay river
# Processing Record 1 of Set 9 | fujin
# Processing Record 2 of Set 9 | buala
# Processing Record 3 of Set 9 | grandview
# Processing Record 4 of Set 9 | pyinmana
# Processing Record 5 of Set 9 | goderich
# Processing Record 6 of Set 9 | pierre
# Processing Record 7 of Set 9 | bose
# Processing Record 8 of Set 9 | bollnas
# Processing Record 9 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 9 | mendeleyevo
# Processing Record 11 of Set 9 | barabai
# Processing Record 12 of Set 9 | sydney
# Processing Record 13 of Set 9 | timmins
# Processing Record 14 of Set 9 | poum
# Processing Record 15 of Set 9 | berga
# Processing Record 16 of Set 9 | tura
# Processing Record 17 of Set 9 | whitehorse
# Processing Record 18 of Set 9 | singkawang
# Processing Record 19 of Set 9 | buenos aires
# Processing Record 20 of Set 9 | shingu
# Processing Record 21 of Set 9 | evensk
# Processing Record 22 of Set 9 | vilyuysk
# Processing Record 23 of Set 9 | olbia
# Processing Record 24 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 25 of Set 9 | berlevag
# Processing Record 26 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 9 | beringovskiy
# Processing Record 28 of Set 9 | mnogovershinnyy
# Processing Record 29 of Set 9 | merauke
# Processing Record 30 of Set 9 | yulara
# Processing Record 31 of Set 9 | akdepe
# Processing Record 32 of Set 9 | ormara
# Processing Record 33 of Set 9 | kushima
# Processing Record 34 of Set 9 | dabhol
# Processing Record 35 of Set 9 | saint george
# Processing Record 36 of Set 9 | ipixuna
# Processing Record 37 of Set 9 | kavaratti
# Processing Record 38 of Set 9 | novoleushkovskaya
# Processing Record 39 of Set 9 | telfs
# Processing Record 40 of Set 9 | jawa
# Processing Record 41 of Set 9 | mori
# Processing Record 42 of Set 9 | ust-ishim
# Processing Record 43 of Set 9 | am timan
# Processing Record 44 of Set 9 | xining
# Processing Record 45 of Set 9 | sibu
# Processing Record 46 of Set 9 | la palma
# Processing Record 47 of Set 9 | melo
# Processing Record 48 of Set 9 | sao felix do xingu
# Processing Record 49 of Set 9 | marsa matruh
# Processing Record 50 of Set 9 | zhangye
# Processing Record 1 of Set 10 | zhigansk
# Processing Record 2 of Set 10 | luderitz
# Processing Record 3 of Set 10 | chiang khong
# Processing Record 4 of Set 10 | mount isa
# Processing Record 5 of Set 10 | roald
# Processing Record 6 of Set 10 | uusikaupunki
# Processing Record 7 of Set 10 | berdigestyakh
# Processing Record 8 of Set 10 | sai buri
# Processing Record 9 of Set 10 | sofiyivka
# Processing Record 10 of Set 10 | honningsvag
# Processing Record 11 of Set 10 | vostok
# Processing Record 12 of Set 10 | phan thiet
# Processing Record 13 of Set 10 | nador
# Processing Record 14 of Set 10 | tranas
# Processing Record 15 of Set 10 | deputatskiy
# Processing Record 16 of Set 10 | oranjemund
# Processing Record 17 of Set 10 | oussouye
# Processing Record 18 of Set 10 | kenai
# Processing Record 19 of Set 10 | lake charles
# Processing Record 20 of Set 10 | ambovombe
# Processing Record 21 of Set 10 | lima
# Processing Record 22 of Set 10 | westport
# Processing Record 23 of Set 10 | kabalo
# Processing Record 24 of Set 10 | mundgod
# Processing Record 25 of Set 10 | tagusao
# Processing Record 26 of Set 10 | talnakh
# Processing Record 27 of Set 10 | hammerfest
# Processing Record 28 of Set 10 | yar-sale
# Processing Record 29 of Set 10 | presidencia roque saenz pena
# Processing Record 30 of Set 10 | shelburne
# Processing Record 31 of Set 10 | chihuahua
# Processing Record 32 of Set 10 | taoudenni
# Processing Record 33 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 10 | san ramon
# Processing Record 35 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 10 | moose factory
# Processing Record 37 of Set 10 | stawell
# Processing Record 38 of Set 10 | balikpapan
# Processing Record 39 of Set 10 | hargeysa
# Processing Record 40 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 41 of Set 10 | urumqi
# Processing Record 42 of Set 10 | haines junction
# Processing Record 43 of Set 10 | ugoofaaru
# Processing Record 44 of Set 10 | khandyga
# Processing Record 45 of Set 10 | sol-iletsk
# Processing Record 46 of Set 10 | acapulco
# Processing Record 47 of Set 10 | zhanakorgan
# Processing Record 48 of Set 10 | kiunga
# Processing Record 49 of Set 10 | kawalu
# Processing Record 50 of Set 10 | renqiu
# Processing Record 1 of Set 11 | loding
# Processing Record 2 of Set 11 | canto do buriti
# Processing Record 3 of Set 11 | villa carlos paz
# Processing Record 4 of Set 11 | meulaboh
# Processing Record 5 of Set 11 | antofagasta
# Processing Record 6 of Set 11 | potosi
# Processing Record 7 of Set 11 | siocon
# Processing Record 8 of Set 11 | katsuura
# Processing Record 9 of Set 11 | yokadouma
# Processing Record 10 of Set 11 | arraial do cabo
# Processing Record 11 of Set 11 | tocopilla
# Processing Record 12 of Set 11 | bentiu
# Processing Record 13 of Set 11 | guajara-mirim
# City not found. Skipping...
# Processing Record 14 of Set 11 | awjilah
# Processing Record 15 of Set 11 | fukue
# Processing Record 16 of Set 11 | cordele
# Processing Record 17 of Set 11 | gardan diwal
# City not found. Skipping...
# Processing Record 18 of Set 11 | pala
# Processing Record 19 of Set 11 | okakarara
# Processing Record 20 of Set 11 | chisec
# Processing Record 21 of Set 11 | krasnorechenskiy
# Processing Record 22 of Set 11 | tanabe
# Processing Record 23 of Set 11 | mishkino
# Processing Record 24 of Set 11 | pteleos
# Processing Record 25 of Set 11 | agidel
# Processing Record 26 of Set 11 | amudat
# Processing Record 27 of Set 11 | kerchevskiy
# Processing Record 28 of Set 11 | bom jesus
# Processing Record 29 of Set 11 | taua
# Processing Record 30 of Set 11 | swan hill
# Processing Record 31 of Set 11 | eureka
# Processing Record 32 of Set 11 | bereda
# Processing Record 33 of Set 11 | ust-tsilma
# Processing Record 34 of Set 11 | tazovskiy
# Processing Record 35 of Set 11 | richards bay
# Processing Record 36 of Set 11 | manggar
# Processing Record 37 of Set 11 | santa comba
# Processing Record 38 of Set 11 | chiredzi
# Processing Record 39 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 40 of Set 11 | kirovsk
# Processing Record 41 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 42 of Set 11 | pangnirtung
# Processing Record 43 of Set 11 | tula
# Processing Record 44 of Set 11 | morondava
# Processing Record 45 of Set 11 | ukiah
# Processing Record 46 of Set 11 | quesnel
# Processing Record 47 of Set 11 | gaillac
# Processing Record 48 of Set 11 | verkhnyaya khava
# Processing Record 49 of Set 11 | sopelana
# Processing Record 50 of Set 11 | sukhothai
# Processing Record 1 of Set 12 | cabedelo
# Processing Record 2 of Set 12 | avinurme
# Processing Record 3 of Set 12 | chicama
# Processing Record 4 of Set 12 | mazamari
# Processing Record 5 of Set 12 | chuy
# Processing Record 6 of Set 12 | aklavik
# Processing Record 7 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 8 of Set 12 | akhmim
# Processing Record 9 of Set 12 | luwuk
# Processing Record 10 of Set 12 | vardo
# Processing Record 11 of Set 12 | maniitsoq
# Processing Record 12 of Set 12 | durban
# Processing Record 13 of Set 12 | constantine
# Processing Record 14 of Set 12 | liepaja
# Processing Record 15 of Set 12 | havelock
# Processing Record 16 of Set 12 | seymchan
# Processing Record 17 of Set 12 | russkaya polyana
# Processing Record 18 of Set 12 | kashary
# Processing Record 19 of Set 12 | ler
# Processing Record 20 of Set 12 | chapais
# Processing Record 21 of Set 12 | thika
# Processing Record 22 of Set 12 | chifeng
# Processing Record 23 of Set 12 | saint-louis
# Processing Record 24 of Set 12 | cururupu
# Processing Record 25 of Set 12 | kyra
# Processing Record 26 of Set 12 | raudeberg
# Processing Record 27 of Set 12 | bouloupari
# Processing Record 28 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 29 of Set 12 | katsiveli
# City not found. Skipping...
# Processing Record 30 of Set 12 | havoysund
# Processing Record 31 of Set 12 | safranbolu
# Processing Record 32 of Set 12 | poso
# Processing Record 33 of Set 12 | port hedland
# Processing Record 34 of Set 12 | yerbogachen
# Processing Record 35 of Set 12 | arroyo
# Processing Record 36 of Set 12 | kokopo
# Processing Record 37 of Set 12 | kyzyl-suu
# Processing Record 38 of Set 12 | dicabisagan
# Processing Record 39 of Set 12 | shu
# Processing Record 40 of Set 12 | nanortalik
# Processing Record 41 of Set 12 | ati
# Processing Record 42 of Set 12 | kankan
# Processing Record 43 of Set 12 | gat
# Processing Record 44 of Set 12 | avera
# Processing Record 45 of Set 12 | traipu
# Processing Record 46 of Set 12 | caohai
# Processing Record 47 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 48 of Set 12 | porto torres
# Processing Record 49 of Set 12 | hervey bay
# Processing Record 50 of Set 12 | tsabong
# Processing Record 1 of Set 13 | oksfjord
# Processing Record 2 of Set 13 | padrauna
# Processing Record 3 of Set 13 | koygorodok
# Processing Record 4 of Set 13 | alofi
# Processing Record 5 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 6 of Set 13 | anadyr
# Processing Record 7 of Set 13 | shakawe
# Processing Record 8 of Set 13 | teguldet
# Processing Record 9 of Set 13 | puerto escondido
# Processing Record 10 of Set 13 | taltal
# Processing Record 11 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 13 | diplo
# Processing Record 13 of Set 13 | hohhot
# Processing Record 14 of Set 13 | alpena
# Processing Record 15 of Set 13 | mountain home
# Processing Record 16 of Set 13 | san vicente
# Processing Record 17 of Set 13 | rincon
# Processing Record 18 of Set 13 | antalaha
# Processing Record 19 of Set 13 | saint-francois
# Processing Record 20 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 21 of Set 13 | kailua
# Processing Record 22 of Set 13 | tiarei
# Processing Record 23 of Set 13 | mosquera
# Processing Record 24 of Set 13 | kaspiysk
# Processing Record 25 of Set 13 | outlook
# Processing Record 26 of Set 13 | camacupa
# Processing Record 27 of Set 13 | dwarka
# Processing Record 28 of Set 13 | leh
# Processing Record 29 of Set 13 | roma
# Processing Record 30 of Set 13 | nsanje
# Processing Record 31 of Set 13 | sobinka
# Processing Record 32 of Set 13 | gizo
# Processing Record 33 of Set 13 | faanui
# Processing Record 34 of Set 13 | buraydah
# Processing Record 35 of Set 13 | nchelenge
# Processing Record 36 of Set 13 | armidale
# Processing Record 37 of Set 13 | zeya
# Processing Record 38 of Set 13 | wazzan
# City not found. Skipping...
# Processing Record 39 of Set 13 | gao
# Processing Record 40 of Set 13 | nelson bay
# Processing Record 41 of Set 13 | skibbereen
# Processing Record 42 of Set 13 | mingaora
# Processing Record 43 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 44 of Set 13 | mitsamiouli
# Processing Record 45 of Set 13 | halifax
# Processing Record 46 of Set 13 | el seibo
# Processing Record 47 of Set 13 | jumla
# Processing Record 48 of Set 13 | dunedin
# Processing Record 49 of Set 13 | iskateley
# Processing Record 50 of Set 13 | san jose
# Processing Record 1 of Set 14 | faya
# Processing Record 2 of Set 14 | kutum
# Processing Record 3 of Set 14 | kursenai
# Processing Record 4 of Set 14 | koutiala
# Processing Record 5 of Set 14 | svobodnyy
# Processing Record 6 of Set 14 | sunrise manor
# Processing Record 7 of Set 14 | japura
# Processing Record 8 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 14 | weihai
# Processing Record 10 of Set 14 | menongue
# Processing Record 11 of Set 14 | putla
# City not found. Skipping...
# Processing Record 12 of Set 14 | tommot
# Processing Record 13 of Set 14 | lamar
# Processing Record 14 of Set 14 | poyarkovo
# Processing Record 15 of Set 14 | baykit
# Processing Record 16 of Set 14 | broken hill
# Processing Record 17 of Set 14 | pochutla
# Processing Record 18 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 14 | bubaque
# Processing Record 20 of Set 14 | nhulunbuy
# Processing Record 21 of Set 14 | dhangadhi
# Processing Record 22 of Set 14 | cayenne
# Processing Record 23 of Set 14 | garowe
# Processing Record 24 of Set 14 | gadsden
# Processing Record 25 of Set 14 | san quintin
# Processing Record 26 of Set 14 | gushikawa
# Processing Record 27 of Set 14 | thinadhoo
# Processing Record 28 of Set 14 | grand forks
# Processing Record 29 of Set 14 | sabang
# Processing Record 30 of Set 14 | barahan
# Processing Record 31 of Set 14 | wajima
# Processing Record 32 of Set 14 | sciacca
# Processing Record 33 of Set 14 | sao jose da laje
# Processing Record 34 of Set 14 | kathmandu
# Processing Record 35 of Set 14 | ust-omchug
# Processing Record 36 of Set 14 | bushehr
# Processing Record 37 of Set 14 | magomeni
# Processing Record 38 of Set 14 | hibbing
# Processing Record 39 of Set 14 | porbandar
# Processing Record 40 of Set 14 | uberlandia
# Processing Record 41 of Set 14 | dmitriyev-lgovskiy
# City not found. Skipping...
# Processing Record 42 of Set 14 | kragujevac
# Processing Record 43 of Set 14 | vygonichi
# Processing Record 44 of Set 14 | bria
# Processing Record 45 of Set 14 | jiuquan
# Processing Record 46 of Set 14 | marzuq
# Processing Record 47 of Set 14 | tautira
# Processing Record 48 of Set 14 | micheweni
# Processing Record 49 of Set 14 | puerto castilla
# Processing Record 50 of Set 14 | acacias
# Processing Record 1 of Set 15 | mandera
# Processing Record 2 of Set 15 | cananeia
# Processing Record 3 of Set 15 | albanel
# Processing Record 4 of Set 15 | aksarayskiy
# Processing Record 5 of Set 15 | ciudad bolivar
# Processing Record 6 of Set 15 | bjornevatn
# Processing Record 7 of Set 15 | chocaman
# Processing Record 8 of Set 15 | erenhot
# Processing Record 9 of Set 15 | penzance
# Processing Record 10 of Set 15 | champerico
# Processing Record 11 of Set 15 | marfino
# Processing Record 12 of Set 15 | jiwani
# Processing Record 13 of Set 15 | lady lake
# Processing Record 14 of Set 15 | leshukonskoye
# Processing Record 15 of Set 15 | taksimo
# Processing Record 16 of Set 15 | anchorage
# Processing Record 17 of Set 15 | jinchang
# Processing Record 18 of Set 15 | cataingan
# Processing Record 19 of Set 15 | galveston
# Processing Record 20 of Set 15 | zhumadian
# Processing Record 21 of Set 15 | tutoia
# Processing Record 22 of Set 15 | severo-yeniseyskiy
# Processing Record 23 of Set 15 | balatonalmadi
# Processing Record 24 of Set 15 | zelenogorskiy
# Processing Record 25 of Set 15 | manosque
# Processing Record 26 of Set 15 | ceuta
# Processing Record 27 of Set 15 | manyana
# Processing Record 28 of Set 15 | sinnamary
# Processing Record 29 of Set 15 | port-cartier
# Processing Record 30 of Set 15 | atbasar
# Processing Record 31 of Set 15 | oros
# Processing Record 32 of Set 15 | aguimes
# Processing Record 33 of Set 15 | debre tabor
# Processing Record 34 of Set 15 | fenoarivo
# Processing Record 35 of Set 15 | kudahuvadhoo
# Processing Record 36 of Set 15 | varkkallai
# Processing Record 37 of Set 15 | geresk
# City not found. Skipping...
# Processing Record 38 of Set 15 | palaiokhora
# City not found. Skipping...
# Processing Record 39 of Set 15 | nago
# Processing Record 40 of Set 15 | bara
# Processing Record 41 of Set 15 | ferkessedougou
# Processing Record 42 of Set 15 | aracuai
# Processing Record 43 of Set 15 | bandar
# Processing Record 44 of Set 15 | mount gambier
# Processing Record 45 of Set 15 | gigmoto
# Processing Record 46 of Set 15 | nadym
# Processing Record 47 of Set 15 | hokitika
# Processing Record 48 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 15 | hualmay
# Processing Record 50 of Set 15 | killybegs
# Processing Record 1 of Set 16 | sucua
# Processing Record 2 of Set 16 | solsvik
# City not found. Skipping...
# Processing Record 3 of Set 16 | abu kamal
# Processing Record 4 of Set 16 | timbangan
# City not found. Skipping...
# Processing Record 5 of Set 16 | wageningen
# Processing Record 6 of Set 16 | mehamn
# Processing Record 7 of Set 16 | kahului
# Processing Record 8 of Set 16 | lagunas
# Processing Record 9 of Set 16 | anjad
# Processing Record 10 of Set 16 | tyukalinsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
weather_data_df = pd.DataFrame(weather_data)
weather_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Vila Velha -20.3297  -40.2925     71.60        78          75
# 1  Ponta Do Sol  32.6667  -17.1000     55.99        80          31
# 2         Apomu   7.3333    4.1833     72.36        96         100
# 3          Hovd  48.0056   91.6419     64.00        27          86
# 4       Rikitea -23.1203 -134.9692     77.05        63          77
# 5         Kapaa  22.0752 -159.3190     78.80        57          20
# 6    Assiniboia  49.6334 -105.9845     55.40        30          97
# 7       Salalah  17.0151   54.0924     82.40        83          75
# 8     Neryungri  56.6709  124.6491     33.01        99         100
# 9      Hamilton  39.1834  -84.5333     57.99        82          55
#
#    Wind Speed Country                 Date
# 0        8.05      BR  2021-04-30 01:54:17
# 1        3.00      PT  2021-04-30 01:54:17
# 2        2.30      NG  2021-04-30 01:54:17
# 3        6.53      MN  2021-04-30 01:52:25
# 4       12.84      PF  2021-04-30 01:54:18
# 5        9.22      US  2021-04-30 01:53:58
# 6       14.97      CA  2021-04-30 01:51:18
# 7        3.44      OM  2021-04-30 01:52:38
# 8        4.47      RU  2021-04-30 01:54:18
# 9        7.56      US  2021-04-30 01:54:18

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
df = weather_data_df[new_column_order]
df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0    Vila Velha      BR  2021-04-30 01:54:17 -20.3297  -40.2925     71.60
# 1  Ponta Do Sol      PT  2021-04-30 01:54:17  32.6667  -17.1000     55.99
# 2         Apomu      NG  2021-04-30 01:54:17   7.3333    4.1833     72.36
# 3          Hovd      MN  2021-04-30 01:52:25  48.0056   91.6419     64.00
# 4       Rikitea      PF  2021-04-30 01:54:18 -23.1203 -134.9692     77.05
# 5         Kapaa      US  2021-04-30 01:53:58  22.0752 -159.3190     78.80
# 6    Assiniboia      CA  2021-04-30 01:51:18  49.6334 -105.9845     55.40
# 7       Salalah      OM  2021-04-30 01:52:38  17.0151   54.0924     82.40
# 8     Neryungri      RU  2021-04-30 01:54:18  56.6709  124.6491     33.01
# 9      Hamilton      US  2021-04-30 01:54:18  39.1834  -84.5333     57.99
#
#    Humidity  Cloudiness  Wind Speed
# 0        78          75        8.05
# 1        80          31        3.00
# 2        96         100        2.30
# 3        27          86        6.53
# 4        63          77       12.84
# 5        57          20        9.22
# 6        30          97       14.97
# 7        83          75        3.44
# 8        99         100        4.47
# 9        82          55        7.56

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
